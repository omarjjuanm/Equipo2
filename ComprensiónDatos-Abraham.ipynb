# %%
import pandas as pd

# %%
diabetes = pd.read_csv("diabetes.csv")

# %%
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Pregnancies: Se refiere al numero de embarazos de la persona. Es una variable cuantitativa (discreta). Se encuentra en los rangos de 0 a 17.
# Glucose: Se refiere al indicador de glucosa de cada persona. Es una variable cuantitativa (discreta). Se ecuentra en los rangos de 0 y 199.
# BloodPreassure: Se refiere al indicador de presion en la sangre de cada persona. Es una variable cuantitativa (discreta). Se ecuentra en los rangos de 0 y 199.
# SkinThickness: Se refiere al indicador de grosor de la piel de cada persona. Es una variable cuantitativa (discreta). Se ecuentra en los rangos de 0 y 99.
# Insulin: Se refiere al indicador de insulina de cada persona. Es una variable cuantitativa (discreta). Se ecuentra en los rangos de 0 y 846.
# BMI: Se refiere al indicador de masa corporal de cada persona. Es una variable cuantitativa (continua). Se ecuentra en los rangos de 0 y 67.1.
# DiabetesPedigreeFunction: Se refiere a la síntesis de la historia de diabetes mellitus en familiares y la relación genética de esos familiares con el sujeto. Es una variable cuantitativa (discreta). Se ecuentra en los rangos de 2.42 y 0.078.
# Age: Se refiere a la edad de cada persona. Es una variable cuantitativa (discreta). Se ecuentra en los rangos de 21 y 81.
# Outcome: Se refiere a si una persona tiene diabetes o no. Es una variable cualitativa ordinal. Toma valores de 0 y 1.

# %% [markdown]
# Basandonos en la media, mediana y desviacion estandar de cada variable se podria generalizar concluyendo que se tiene una alta desviacion estandar. Para ver si se pueden hacer predicciones sobre la diabetes en las personas habria que sacar que tanto se ajustan los datos a la linea.

# %%
#Edad
#Se puede obtener la media, mediana y moda para
mean_age = diabetes['Age'].mean()
median_age =diabetes['Age'].median()
mode_age = diabetes['Age'].mode()
print("Mean_age:",mean_age)
print("Median_age:",median_age)
print("Mode_age:",mode_age)
# Out:
# Mean_age: 33.240885416666664
# Median_age: 29.0
# Mode_age: 0    22
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt 

import pandas as pd  
import seaborn as sns

# %%
ax = sns.boxplot(x="Outcome", y="BMI", 
                data=diabetes)
ax = sns.stripplot(x="Outcome", y="BMI",
                   data=diabetes, jitter=True,
                   edgecolor="gray")

# %%
ax = sns.boxplot(x="Outcome", y="Age", 
                data=diabetes)
ax = sns.stripplot(x="Outcome", y="Age",
                   data=diabetes, jitter=True,
                   edgecolor="gray")

# %%
ax = sns.boxplot(x="Outcome", y="Glucose", 
                data=diabetes)
ax = sns.stripplot(x="Outcome", y="Glucose",
                   data=diabetes, jitter=True,
                   edgecolor="gray")

# %%
ax = sns.boxplot(x="Outcome", y="Insulin", 
                data=diabetes)
ax = sns.stripplot(x="Outcome", y="Insulin",
                   data=diabetes, jitter=True,
                   edgecolor="gray")

# %%
ax = sns.boxplot(x="Outcome", y="DiabetesPedigreeFunction", 
                data=diabetes)
ax = sns.stripplot(x="Outcome", y="DiabetesPedigreeFunction",
                   data=diabetes, jitter=True,
                   edgecolor="gray")

# %%
ax = sns.boxplot(x="Outcome", y="Pregnancies", 
                data=diabetes)
ax = sns.stripplot(x="Outcome", y="Pregnancies",
                   data=diabetes, jitter=True,
                   edgecolor="gray")

# %%
ax = sns.boxplot(x="Outcome", y="BloodPressure", 
                data=diabetes)
ax = sns.stripplot(x="Outcome", y="BloodPressure",
                   data=diabetes, jitter=True,
                   edgecolor="gray")

# %%
ax = sns.boxplot(x="Outcome", y="SkinThickness", 
                data=diabetes)
ax = sns.stripplot(x="Outcome", y="SkinThickness",
                   data=diabetes, jitter=True,
                   edgecolor="gray")

# %%
correlation_matrix = diabetes.corr().round(2)

# %%
# use the heatmap function from seaborn to plot the correlation matrix
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# plot a histogram showing the distribution of the target values
sns.displot(diabetes['BMI'], bins=10)
plt.show()

# %%
sns.displot(diabetes['Age'], bins=10)
plt.show()

# %%
sns.displot(diabetes['BloodPressure'], bins=10)
plt.show()

# %%
sns.displot(diabetes['Insulin'], bins=10)
plt.show()

# %%
sns.displot(diabetes['Glucose'], bins=10)
plt.show()

# %%
sns.displot(diabetes['SkinThickness'], bins=10)
plt.show()

# %%
¿Hay alguna variable que no aporta información? La variable SkinThickness y BloodPressure aportan muy poca informacion ya se distribuye de la misma forma en cualquier Outcome.   

Si tuvieras que eliminar variables, ¿cuáles quitarías y por qué? SkinThickness y BloodPressure debido a que es nula su aportacion. Insulin y SkinThickness tienen una desviacion estandar muy alta por lo que podria no ser util para el analisis.

¿Existen variables que tengan datos extraños? Insuline, bloodpressure y BMI tienen como minimo 0 y no hay personas que puedan tener en cero alguna de estas variables.

Si comparas las variables, ¿todas están en rangos similares? ¿Crees que esto afecte? No, estan en rangos similares porque cada variable tiene su propio rango de medición 

¿Puedes encontrar grupos qué se parezcan? ¿Qué grupos son estos? No, porque las variables aunque se pueden relacionar, son independientes en su medición.
