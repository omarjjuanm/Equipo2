# %%
import pandas as pd

# %%
datos = pd.read_csv("diabetes.csv")

# %%
datos
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
datos.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
datos.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Al ordenar estos datos los podemos analizar para llegar a conclusiones que sena de provecho en el área que se esta estudiando. En este caso se nos presentan datos relacionados con el tema de la Dibetes con variables como el no. de embarazos, el nivel de glucosa, la presión sanguínea, el indice de masa corporal, el historial médico, la edad y un indicador de diabetes. Lo que se puede ver en estos datos es la media, la mediana, la desviación estandar y el rango de cada variable, con esta información notamos que existe una alta desviación estandar, por lo que en algunas variables no sería adecuado utilizar sus valores para el análisis. También podemos ver que la edad promedio de las personas en este análisis es de 33 años, y se presenta un nivel de glucosa promedio de 120mg/dl, lo que se considera normal al ser menor de los 140mg/dl, y el promedio de los embarazos por persona es de 3.

# %%
#Edad
#Se puede obtener la media, mediana y moda para
mean_age = datos['Age'].mean()
median_age =datos['Age'].median()
mode_age = datos['Age'].mode()
print("Meedia Age:",mean_age)
print("Mediana Age:",median_age)
print("Moda Age:",mode_age)
# Out:
# Meedia Age: 33.240885416666664
# Mediana Age: 29.0
# Moda Age: 0    22
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt 

import pandas as pd  
import seaborn as sns

# %%
ax = sns.boxplot(x="Outcome", y="BMI", 
                data=datos)
ax = sns.stripplot(x="Outcome", y="BMI",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %%
ax = sns.boxplot(x="Outcome", y="Age", 
                data=datos)
ax = sns.stripplot(x="Outcome", y="Age",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %%
ax = sns.boxplot(x="Outcome", y="Glucose", 
                data=datos)
ax = sns.stripplot(x="Outcome", y="Glucose",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %%
ax = sns.boxplot(x="Outcome", y="Insulin", 
                data=datos)
ax = sns.stripplot(x="Outcome", y="Insulin",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %%
ax = sns.boxplot(x="Outcome", y="DiabetesPedigreeFunction", 
                data=datos)
ax = sns.stripplot(x="Outcome", y="DiabetesPedigreeFunction",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %%
ax = sns.boxplot(x="Outcome", y="Pregnancies", 
                data=datos)
ax = sns.stripplot(x="Outcome", y="Pregnancies",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %%
ax = sns.boxplot(x="Outcome", y="BloodPressure", 
                data=datos)
ax = sns.stripplot(x="Outcome", y="BloodPressure",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %%
ax = sns.boxplot(x="Outcome", y="SkinThickness", 
                data=datos)
ax = sns.stripplot(x="Outcome", y="SkinThickness",
                   data=datos, jitter=True,
                   edgecolor="gray")

# %%
correlation_matrix = datos.corr().round(2)

# %%
# use the heatmap function from seaborn to plot the correlation matrix
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# plot a histogram showing the distribution of the target values
sns.displot(file['BMI'], bins=10)
plt.show()

# %%
sns.displot(datos['Age'], bins=10)
plt.show()

# %%
sns.displot(datos['BloodPressure'], bins=10)
plt.show()

# %%
sns.displot(datos['Insulin'], bins=10)
plt.show()

# %%
sns.displot(datos['Glucose'], bins=10)
plt.show()

# %%
sns.displot(datos['SkinThickness'], bins=10)
plt.show()

# %% [markdown]
# - ¿Hay alguna variable que no aporta información?
#     Las variables 'SkinThickness' y 'BloodPressure'
# - Si tuvieras que eliminar variables, ¿cuáles quitarías y por qué?
#      Las variables 'SkinThickness' y 'BloodPressure'ya que el valor en la desviación estándar que presentan es muy alto, por lo que no sería adecuado el usar los valores arrojados dentro de esas variables para cualquier tipo de análisis de estos datos
# - ¿Existen variables que tengan datos extraños?
#     Las variables 'Glucosa', 'Insuline', 'bloodpressure' y 'BMI' presentan una gran variabilidad entre sus datos, incluso existen datos que hacen que el rango de estas variables sea 0, lo cual no es lógico al ser valores o porcentajes que no aplican en personas normales.
# - Si comparas las variables, ¿todas están en rangos similares? ¿Crees que esto afecte?
#     A pesar de que algunas variables tienen un valor mínimo igual o similiar, esto no afecta ya que cada variable tiene su propio rango y los valores no son los mismos al tratarse de otro tipo de medición.
# - ¿Puedes encontrar grupos qué se parezcan? ¿Qué grupos son estos?
#     Como mencionaba en la respuesta anterior, pueden existir algunos datos iguales pero no se esta utilizando la misma mediión por lo que no pueden parecerse.
